# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('deliveries.csv')

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
# match_id            150460 non-null int64
# inning              150460 non-null int64
# batting_team        150460 non-null object
# bowling_team        150460 non-null object
# over                150460 non-null int64
# ball                150460 non-null int64
# batsman             150460 non-null object
# non_striker         150460 non-null object
# bowler              150460 non-null object
# is_super_over       150460 non-null int64
# wide_runs           150460 non-null int64
# bye_runs            150460 non-null int64
# legbye_runs         150460 non-null int64
# noball_runs         150460 non-null int64
# penalty_runs        150460 non-null int64
# batsman_runs        150460 non-null int64
# extra_runs          150460 non-null int64
# total_runs          150460 non-null int64
# player_dismissed    7438 non-null object
# dismissal_kind      7438 non-null object
# ...

# %%
df['is_super_over'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### 1.Display bowler wise super over count

# %%
a = df.groupby(['bowler']).is_super_over.unique()
a
# Out:
# bowler
# A Ashish Reddy    [0]
# A Chandila        [0]
# A Choudhary       [0]
# A Flintoff        [0]
# A Kumble          [0]
#                  ...
# YA Abdulla        [0]
# YK Pathan         [0]
# YS Chahal         [0]
# Yuvraj Singh      [0]
# Z Khan            [0]
# Name: is_super_over, Length: 356, dtype: object

# %%
a = df.groupby(['bowler']).is_super_over.max().sort_values(ascending=False)
a.max()
# Out:
# 1

# %%
a.head(12)
# Out:
# bowler
# JP Faulkner       11
# JJ Bumrah          8
# CH Morris          7
# Kamran Khan        7
# R Vinay Kumar      7
# DW Steyn           6
# R Rampaul          6
# SP Narine          6
# UT Yadav           6
# J Theron           5
# M Muralitharan     4
# BAW Mendis         4
# Name: is_super_over, dtype: int64

# %% [markdown]
# a.tail()

# %%
a = df.groupby(['bowler']).is_super_over.sum().sort_values(ascending=False)

# %%
a.head(20)
# Out:
# bowler
# JP Faulkner          11
# JJ Bumrah             8
# CH Morris             7
# Kamran Khan           7
# R Vinay Kumar         7
# DW Steyn              6
# R Rampaul             6
# SP Narine             6
# UT Yadav              6
# J Theron              5
# M Muralitharan        4
# BAW Mendis            4
# MG Johnson            4
# Harbhajan Singh       0
# HH Pandya             0
# Gurkeerat Singh       0
# Gagandeep Singh       0
# HV Patel              0
# Harmeet Singh (2)     0
# Harmeet Singh         0
# Name: is_super_over, dtype: int64

# %% [markdown]
# ### 2. Display bowler wise wicket count

# %%
wickets = df.groupby(['bowler']).
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#     842         else:
# --> 843             result = getattr(values, meth)(axis)
#     844
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#
# TypeError: '>=' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
catch = df(['fielder'])['dismissal_kind'=='caught']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-c5546825bc8b> in <module>
# ----> 1 catch = df.groupby(['fielder'])['dismissal_kind'=='caught']
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266         else:
#     267             if key not in self.obj:
# --> 268                 raise KeyError("Column not found: {key}".format(key=key))
#     269             return self._gotitem(key, ndim=1)
#     270
#
# KeyError: 'Column not found: False'

# %%
catch
# Out:
# fielder
# A Ashish Reddy    run out
# A Chandila         caught
# A Chopra          run out
# A Flintoff         caught
# A Kumble           caught
#                    ...
# YV Takawale       stumped
# Yashpal Singh      caught
# Younis Khan        caught
# Yuvraj Singh      run out
# Z Khan            run out
# Name: dismissal_kind, Length: 451, dtype: object

# %%
catch.max()
# Out:
# 'stumped'

# %%
catch.max(dismissal_kind)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-26616d021110> in <module>
# ----> 1 catch.max(dismissal_kind)
#
# NameError: name 'dismissal_kind' is not defined

# %%
catch.sum()
# Out:
# 'run outcaughtrun outcaughtcaughtrun outrun outcaughtrun outrun outcaughtrun outcaughtcaughtrun outrun outrun outstumpedcaughtcaughtstumpedrun outrun outcaughtrun outrun outcaughtrun outrun outrun outcaughtrun outrun outcaughtcaughtrun outcaughtcaughtstumpedrun outcaughtrun outcaughtrun outrun outstumpedrun outcaughtrun outcaughtcaughtcaughtrun outcaughtrun outcaughtcaughtcaughtcaughtrun outrun outcaughtcaughtrun outcaughtstumpedcaughtrun outrun outrun outcaughtrun outrun outrun outcaughtcaughtcaughtrun outrun outcaughtrun outcaughtcaughtcaughtrun outcaughtcaughtcaughtrun outcaughtrun outstumpedrun outcaughtcaughtcaughtcaughtcaughtcaughtrun outcaughtrun outrun outrun outrun outrun outrun outstumpedrun outcaughtcaughtrun outrun outstumpedcaughtcaughtcaughtrun outcaughtrun outrun outrun outrun outcaughtcaughtrun outrun outcaughtcaughtrun outcaughtcaughtcaughtrun outrun outcaughtcaughtrun outrun outcaughtrun outstumpedrun outrun outcaughtrun outrun outcaughtcaughtrun outcaughtrun outcau
# ...

# %%
catch = df[df['dismissal_kind']=='caught']

# %%
catch
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 206            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 150309       636       1          Sunrisers Hyderabad
# 150326       636       1          Sunrisers Hyderabad
# 150402       636       2  Royal Challengers Bangalore
# 150422       636       2  Royal Challengers Bangalore
# 150438       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball         batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5       DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3        S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2    MC Henriques  Yuvraj Singh
# ...

# %%
catch['fielder'].max()
# Out:
# 'Z Khan'
